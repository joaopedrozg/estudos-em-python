# %%
import quandl

# %%
mydata_01 = quandl.get("FRED/GDP")

# %%
mydata_01.tail()
# Out:
#                 Value
# Date
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23187.042

# %%
mydata_01.head()
# Out:
#               Value
# Date
# 1947-01-01  243.164
# 1947-04-01  245.968
# 1947-07-01  249.585
# 1947-10-01  259.745
# 1948-01-01  265.742

# %%
import pandas as pd

# %%
mydata_01.to_csv('C:/Users/ITJ-PC-6058/Documents/Area de Trabalho/JoãoPedro/example_01.csv')

# %%
mydata_02 = pd.read_CSV('C:/Users/ITJ-PC-6058/Documents/Area de Trabalho/JoãoPedro/example_01.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-eea929bf6c87> in <module>
# ----> 1 mydata_02 = pd.read_CSV('C:/Users/ITJ-PC-6058/Documents/Area de Trabalho/JoãoPedro/example_01.csv')
#
# AttributeError: module 'pandas' has no attribute 'read_CSV'

# %%
mydata_03 = pd.read_excel('C:/Users/ITJ-PC-6058/Desktop/xap.xlsx')

# %%
mydata_03
# Out:
#            CTRC      NF       REMETENTE         PAGADOR/ABC    DESTINATARIO  \
# 0   CCI018839-5    6764  BNT NUTRAC UTI  BNT NUTRAC UTIC A.  OESTE DISTRIBU
# 1   ERM064207-0   10950   TOP NORTE COM  TOP NORTE COM D A.  FUNDO MUNICIPA
# 2   ERM064336-0  411714  SANDERO INDUST  SANDERO INDUSTR A.  MERCEARIA J.S.
# 3   ERM064366-1  274071  CENTERMEDI COM  CENTERMEDI COME A.  FUNDO MUNICIPA
# 4   ERM064450-1  411638  SANDERO INDUST  SANDERO INDUSTR A.  UTILIDADES LON
# 5   ERM064461-7  411579  SANDERO INDUST  SANDERO INDUSTR A.  SLAIN FRANCO R
# 6   ERM064467-6  411566  SANDERO INDUST  SANDERO INDUSTR A.  ALESSANDRA MAC
# 7   ERM064480-3     125  MEDICINA DIAGN  MEDICINA DIAGNO B.   OGATA E KLOCK
# 8   ERM064481-1      28  ERECHIM CENTRO  ERECHIM CENTRO  C.   RAFAEL ANGELO
# 9   ERM064520-6  271605   CAVALETTI S/A  N E S REPRESENT ..  N E S REPRESEN
# 10  FBE451983-3   11312  DENTAL SHOW CO  DENTAL SHOW COM A.  FUNDO MUNICIPA
# ...
